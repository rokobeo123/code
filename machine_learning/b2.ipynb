# %%
def abc():
    return 'abc'
print(abc())
def abc(a):
    return a
print(abc(123))
def mmb(*ten):
    for i in ten:
        print(i,end = ' ')
mmb(1,2,3,4,5)
a=input()
b=input()
a=int(a)
b=int(b)
kq= 'true' if a>b else 'false'
print(kq)
